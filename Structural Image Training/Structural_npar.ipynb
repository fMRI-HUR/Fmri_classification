# %%
import os
import nibabel as nib
import numpy as np

imgloc = 'D:\\strucdata\\HRP\\12227_anat.nii'

# %%
imgdata = nib.load(imgloc)
imgdata = imgdata.get_fdata()

# %%
imgdata = np.array(imgdata)

# %%
print(np.max(imgdata))
print(np.min(imgdata))
print(np.mean(imgdata))
# Out:
# 9257.0
# 0.0
# 376.4248658348532

# %%
import matplotlib.pyplot as plt
print(imgdata[100:150,100:150,60])

plt.imshow(imgdata[100:150,100:150,60],cmap='Greys')
plt.imshow(imgdata[:,:,60],cmap='Greys')
# Out:
# [[1297. 1865. 1741. ... 1662. 1661. 1608.]
#  [1476. 1600. 2095. ... 1813. 1798. 1763.]
#  [1599. 1495. 1950. ... 1691. 1731. 1693.]
#  ...
#  [1568. 1469. 1386. ... 1646. 1680. 1803.]
#  [1480. 1456. 1305. ... 1810. 1827. 1877.]
#  [1357. 1572. 1431. ... 1768. 1731. 1741.]]
